# %% [markdown]
# ## Web Scraping

# %%
# I choose to web scrap: "The Complete List of Unicorn Companies"
# By the CB Insights, it incloudes startups from all over the world
# Primero importaremos las librerías a utilizar

import re
import requests
import pandas as pd
import lxml.html as lh


from bs4 import BeautifulSoup

# %%
# Definiremos el url de donde extraeremos la información 

url = 'https://www.cbinsights.com/research-unicorn-companies'

# %%
html = requests.get(url).content

# %%
html[0:300]
# Out:
# b'<!DOCTYPE html>\n<html>\n\n\t\n\t<head>\n\t\t\t\t\t\t\t\t\t<meta name="iy453p9485yheisruhs5" content="" />\n\t\t\t\t\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n\t\t<meta http-equiv="content-type" content="text/html; charset=utf-8" />\n\n\t\t<title>The Complete List Of Unicorn Companies</title>\n\n\t\t<meta '

# %%
type(html)
# Out:
# bytes

# %%
soup = BeautifulSoup(html, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="" name="iy453p9485yheisruhs5"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <title>The Complete List Of Unicorn Companies</title>
# <meta content="A unicorn is a private company or startup with a valuation over $1 billion. Check out our 2020 updated list of every unicorn company around the globe, their top investors, and more." name="description"/>
# <meta content="unicorn companies,billion dollar startups,unicorn startups,unicorn list" name="keywords"/>
# <link href="https://www.cbinsights.com/research-unicorn-companies" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="The Complete List Of Unicorn Companies" property="og:title"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="" name="iy453p9485yheisruhs5"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <title>
#    The Complete List Of Unicorn Companies
#   </title>
#   <meta content="A unicorn is a private company or startup with a valuation over $1 billion. Check out our 2020 updated list of every unicorn company around the globe, their top investors, and more." name="description"/>
#   <meta content="unicorn companies,billion dollar startups,unicorn startups,unicorn list" name="keywords"/>
#   <link href="https://www.cbinsights.com/research-unicorn-companies" rel="canonical"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="article" property="og:type"/>
#   <meta content="The Complete List Of Unicorn Companies" property="og:title"/>
# ...

# %%
soup.table
# Out:
# <table class="sortable-theme-bootstrap" data-sortable="">
# <thead>
# <tr>
# <th>Company</th>
# <th data-sorted="true" width="120">Valuation ($B)</th>
# <th>Date Joined</th>
# <th>Country</th>
# <th>City</th>
# <th>Industry</th>
# <th data-sortable="false">Select Investors</th>
# </tr>
# </thead>
# <tr>
# <td><a href="https://www.cbinsights.com/company/bytedance">Bytedance</a></td>
# <td data-value="140">$140</td>
# <td>4/7/2017</td>
# <td>China</td>
# <td>Beijing</td>
# <td>Artificial intelligence</td>
# <td>Sequoia Capital China, SIG Asia Investments, Sina Weibo, Softbank Group</td>
# </tr>
# <tr>
# <td><a href="https://www.cbinsights.com/company/stripe">Stripe</a></td>
# <td data-value="95">$95</td>
# <td>1/23/2014</td>
# <td>United States</td>
# <td>San Francisco</td>
# <td>Fintech</td>
# <td>Khosla Ventures, LowercaseCapital, capitalG</td>
# </tr>
# <tr>
# <td><a href="https://www.cbinsights.com/company/space-exploration-technologies">SpaceX</a></td>
# ...

# %%
soup.table['class']
# Out:
# ['sortable-theme-bootstrap']

# %%
# definir y extraer table rows 
page = requests.get(url)
doc = lh.fromstring(page.content)
tr_elements = doc.xpath('//tr')

# %%
# Here we check if the table rows have the same width
checking_length = [len(T) for T in tr_elements[:12]]

# %%
checking_length
# Out:
# [7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7]

# %%
# Parse Table Header
tr_elements = doc.xpath('//tr')

col=[]
i=0

for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print(i,name)
    col.append((name,[]))
# Out:
# 1 Company
# 2 Valuation ($B)
# 3 Date Joined
# 4 Country
# 5 City
# 6 Industry
# 7 Select Investors
